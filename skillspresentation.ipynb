# %% [markdown]
# <a href="https://colab.research.google.com/github/ljm642/Assignment2/blob/main/skillspresentation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#mount drive

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#import relevant libraries

import pandas as pd
import IPython.display as IPD

# %%
#Reading the CSV files of Author, Articles and Paper counts

article_df = pd.read_csv('/content/drive/MyDrive/skills-assessment-2/articles.HLA-A.csv')
author_df = pd.read_csv('/content/drive/MyDrive/skills-assessment-2/authors.HLA-A.csv')
paper_counts_df = pd.read_csv('/content/drive/MyDrive/skills-assessment-2/paper_counts.csv')

# %%
IPD.display(article_df)
# Out:
#           PMID                                              Title  \
# 0     10551415  Role of anchor residues in peptide binding to ...
# 1     10551419  Characterisation of a novel HLA-A pseudogene, ...
# 2     10551420  Identification of 4 different alternatively sp...
# 3     10551424  HLA-A typing by reference strand-mediated conf...
# 4     10551426  The HLA dictionary 1999: a summary of HLA-A, -...
# ...        ...                                                ...
# 5141  38041496  Identification of the novel HLA-A*03:453 allel...
# 5142  38044808  Characterization of the novel HLA-A*02:01:01:2...
# 5143  38048969  Diversity of HLA-A, -B, -C, -DRB1, and -DQB1 a...
# 5144  38065105  SARS-CoV-2 immune response and reinfection in ...
# 5145  38073008  The novel HLA-A*30:01:25 allele found in a Kor...
#
#                                                Abstract       ISSN  \
# 0     To investigate the role of anchor residues in ...  0001-2815
# 1     During the development of an HLA-A polymerase ...  0001-2815
# 2     During the development of a sequencing based t...  0001-2815
# 3     HLA typing of class I loci by reference strand...  0001-2815
# 4     This report presents serologic equivalents of ...  0001-2815
# ...                                                 ...        ...
# 5141  HLA-A*03:453 differs from HLA-A*03:02:01:01 by...  2059-2310
# 5142  HLA-A*02:01:01:243 differs from the HLA-A*02:0...  2059-2310
# 5143  Kazakhstan is a transcontinental former Soviet...  1879-0038
# 5144  Immune response to pathogens, including corona...  1606-7916
# 5145  The novel HLA-A*30:01:25 allele differs from H...  2059-2310
#
#                       Journal           Location  Year FirstAuthorForename  \
# 0             Tissue antigens        (54) 325-32  1999                   N
# 1             Tissue antigens         (54) 360-9  1999                   F
# 2             Tissue antigens         (54) 370-8  1999                   L
# 3             Tissue antigens         (54) 400-4  1999                 D M
# 4             Tissue antigens        (54) 409-37  1999                 G M
# ...                       ...                ...   ...                 ...
# 5141                      HLA  10.1111/tan.15311  2023              Yanmin
# 5142                      HLA  10.1111/tan.15312  2023            Diamanto
# 5143                     Gene       (896) 148062  2023         Abdelhafidh
# 5144  Salud publica de Mexico         (66) 14-16  2023              Victor
# 5145                      HLA  10.1111/tan.15267  2023             Jongmin
#
#      FirstAuthorLastname FirstAuthorInitials  \
# 0                 Yamada                   N
# 1               Williams                   F
# 2               Norgaard                   L
# 3                 Turner                  DM
# 4              Schreuder                  GM
# ...                  ...                 ...
# 5141                  He                   Y
# 5142            Kouniaki                   D
# 5143              Hajjej                   A
# 5144             Monteón                   V
# 5145                 Kim                   J
#
#                                  FirstAuthorAffiliation
# 0     Division of Viral Immunology, Center for AIDS ...
# 1     Northern Ireland Regional Histocompatibility a...
# 2     Department of Clinical Immunology, University ...
# 3     Department of Histocompatibility and Immunogen...
# 4     World Marrow Donor Association, Leiden, The Ne...
# ...                                                 ...
# 5141  HLA Typing Laboratory, Blood Center of Zhejian...
# 5142  Immunology and Histocompatibility Department, ...
# 5143  Department of Immunogenetics, National Blood T...
# 5144  Centro Investigaciones Biomédicas, Universidad...
# 5145  Department of Laboratory Medicine, Pusan Natio...
#
# [5146 rows x 11 columns]

# %%
#Adding the FullName column for the missing values count and for the further analysing purpose because this dataframe has so many similar Lastnames.

article_df['FullName_1'] = article_df['FirstAuthorForename'].astype(str) + ' ' + article_df['FirstAuthorLastname'].astype(str)

# Displaying the Dataframe with the FullName column
IPD.display(article_df)
# Out:
#           PMID                                              Title  \
# 0     10551415  Role of anchor residues in peptide binding to ...
# 1     10551419  Characterisation of a novel HLA-A pseudogene, ...
# 2     10551420  Identification of 4 different alternatively sp...
# 3     10551424  HLA-A typing by reference strand-mediated conf...
# 4     10551426  The HLA dictionary 1999: a summary of HLA-A, -...
# ...        ...                                                ...
# 5141  38041496  Identification of the novel HLA-A*03:453 allel...
# 5142  38044808  Characterization of the novel HLA-A*02:01:01:2...
# 5143  38048969  Diversity of HLA-A, -B, -C, -DRB1, and -DQB1 a...
# 5144  38065105  SARS-CoV-2 immune response and reinfection in ...
# 5145  38073008  The novel HLA-A*30:01:25 allele found in a Kor...
#
#                                                Abstract       ISSN  \
# 0     To investigate the role of anchor residues in ...  0001-2815
# 1     During the development of an HLA-A polymerase ...  0001-2815
# 2     During the development of a sequencing based t...  0001-2815
# 3     HLA typing of class I loci by reference strand...  0001-2815
# 4     This report presents serologic equivalents of ...  0001-2815
# ...                                                 ...        ...
# 5141  HLA-A*03:453 differs from HLA-A*03:02:01:01 by...  2059-2310
# 5142  HLA-A*02:01:01:243 differs from the HLA-A*02:0...  2059-2310
# 5143  Kazakhstan is a transcontinental former Soviet...  1879-0038
# 5144  Immune response to pathogens, including corona...  1606-7916
# 5145  The novel HLA-A*30:01:25 allele differs from H...  2059-2310
#
#                       Journal           Location  Year FirstAuthorForename  \
# 0             Tissue antigens        (54) 325-32  1999                   N
# 1             Tissue antigens         (54) 360-9  1999                   F
# 2             Tissue antigens         (54) 370-8  1999                   L
# 3             Tissue antigens         (54) 400-4  1999                 D M
# 4             Tissue antigens        (54) 409-37  1999                 G M
# ...                       ...                ...   ...                 ...
# 5141                      HLA  10.1111/tan.15311  2023              Yanmin
# 5142                      HLA  10.1111/tan.15312  2023            Diamanto
# 5143                     Gene       (896) 148062  2023         Abdelhafidh
# 5144  Salud publica de Mexico         (66) 14-16  2023              Victor
# 5145                      HLA  10.1111/tan.15267  2023             Jongmin
#
#      FirstAuthorLastname FirstAuthorInitials  \
# 0                 Yamada                   N
# 1               Williams                   F
# 2               Norgaard                   L
# 3                 Turner                  DM
# 4              Schreuder                  GM
# ...                  ...                 ...
# 5141                  He                   Y
# 5142            Kouniaki                   D
# 5143              Hajjej                   A
# 5144             Monteón                   V
# 5145                 Kim                   J
#
#                                  FirstAuthorAffiliation          FullName_1
# 0     Division of Viral Immunology, Center for AIDS ...            N Yamada
# 1     Northern Ireland Regional Histocompatibility a...          F Williams
# 2     Department of Clinical Immunology, University ...          L Norgaard
# 3     Department of Histocompatibility and Immunogen...          D M Turner
# 4     World Marrow Donor Association, Leiden, The Ne...       G M Schreuder
# ...                                                 ...                 ...
# 5141  HLA Typing Laboratory, Blood Center of Zhejian...           Yanmin He
# 5142  Immunology and Histocompatibility Department, ...   Diamanto Kouniaki
# 5143  Department of Immunogenetics, National Blood T...  Abdelhafidh Hajjej
# 5144  Centro Investigaciones Biomédicas, Universidad...      Victor Monteón
# 5145  Department of Laboratory Medicine, Pusan Natio...         Jongmin Kim
#
# [5146 rows x 12 columns]

# %% [markdown]
# Finding the missing count of values in articles dataframe

# %%
articles_missing_count = article_df.isnull().sum()
IPD.display(articles_missing_count)
# Out:
# PMID                       0
# Title                      0
# Abstract                   0
# ISSN                       0
# Journal                    0
# Location                  23
# Year                       0
# FirstAuthorForename        4
# FirstAuthorLastname        3
# FirstAuthorInitials       11
# FirstAuthorAffiliation    39
# FullName_1                 0
# dtype: int64

# %% [markdown]
# Removing the missing values rows based on the important data(PMID,FirstAuthorForename,FirstAuthorLastname,FirstAuthorInitials)

# %%
# Dropping rows where 'PMID', 'Year', 'FirstAuthorForename', or 'FirstAuthorLastname' are missing in the articles dataframe
articles_df = article_df.dropna(subset=['PMID', 'Year', 'FirstAuthorForename', 'FirstAuthorLastname','FirstAuthorInitials'])
missing_values_cleaned_articles = articles_df.isnull().sum()
IPD.display(missing_values_cleaned_articles)
# Out:
# PMID                       0
# Title                      0
# Abstract                   0
# ISSN                       0
# Journal                    0
# Location                  22
# Year                       0
# FirstAuthorForename        0
# FirstAuthorLastname        0
# FirstAuthorInitials        0
# FirstAuthorAffiliation    36
# FullName_1                 0
# dtype: int64

# %% [markdown]
# Displaying the Article dataframe after removing the missing value rows

# %%
IPD.display(articles_df)
# Out:
#           PMID                                              Title  \
# 0     10551415  Role of anchor residues in peptide binding to ...
# 1     10551419  Characterisation of a novel HLA-A pseudogene, ...
# 2     10551420  Identification of 4 different alternatively sp...
# 3     10551424  HLA-A typing by reference strand-mediated conf...
# 4     10551426  The HLA dictionary 1999: a summary of HLA-A, -...
# ...        ...                                                ...
# 5141  38041496  Identification of the novel HLA-A*03:453 allel...
# 5142  38044808  Characterization of the novel HLA-A*02:01:01:2...
# 5143  38048969  Diversity of HLA-A, -B, -C, -DRB1, and -DQB1 a...
# 5144  38065105  SARS-CoV-2 immune response and reinfection in ...
# 5145  38073008  The novel HLA-A*30:01:25 allele found in a Kor...
#
#                                                Abstract       ISSN  \
# 0     To investigate the role of anchor residues in ...  0001-2815
# 1     During the development of an HLA-A polymerase ...  0001-2815
# 2     During the development of a sequencing based t...  0001-2815
# 3     HLA typing of class I loci by reference strand...  0001-2815
# 4     This report presents serologic equivalents of ...  0001-2815
# ...                                                 ...        ...
# 5141  HLA-A*03:453 differs from HLA-A*03:02:01:01 by...  2059-2310
# 5142  HLA-A*02:01:01:243 differs from the HLA-A*02:0...  2059-2310
# 5143  Kazakhstan is a transcontinental former Soviet...  1879-0038
# 5144  Immune response to pathogens, including corona...  1606-7916
# 5145  The novel HLA-A*30:01:25 allele differs from H...  2059-2310
#
#                       Journal           Location  Year FirstAuthorForename  \
# 0             Tissue antigens        (54) 325-32  1999                   N
# 1             Tissue antigens         (54) 360-9  1999                   F
# 2             Tissue antigens         (54) 370-8  1999                   L
# 3             Tissue antigens         (54) 400-4  1999                 D M
# 4             Tissue antigens        (54) 409-37  1999                 G M
# ...                       ...                ...   ...                 ...
# 5141                      HLA  10.1111/tan.15311  2023              Yanmin
# 5142                      HLA  10.1111/tan.15312  2023            Diamanto
# 5143                     Gene       (896) 148062  2023         Abdelhafidh
# 5144  Salud publica de Mexico         (66) 14-16  2023              Victor
# 5145                      HLA  10.1111/tan.15267  2023             Jongmin
#
#      FirstAuthorLastname FirstAuthorInitials  \
# 0                 Yamada                   N
# 1               Williams                   F
# 2               Norgaard                   L
# 3                 Turner                  DM
# 4              Schreuder                  GM
# ...                  ...                 ...
# 5141                  He                   Y
# 5142            Kouniaki                   D
# 5143              Hajjej                   A
# 5144             Monteón                   V
# 5145                 Kim                   J
#
#                                  FirstAuthorAffiliation          FullName_1
# 0     Division of Viral Immunology, Center for AIDS ...            N Yamada
# 1     Northern Ireland Regional Histocompatibility a...          F Williams
# 2     Department of Clinical Immunology, University ...          L Norgaard
# 3     Department of Histocompatibility and Immunogen...          D M Turner
# 4     World Marrow Donor Association, Leiden, The Ne...       G M Schreuder
# ...                                                 ...                 ...
# 5141  HLA Typing Laboratory, Blood Center of Zhejian...           Yanmin He
# 5142  Immunology and Histocompatibility Department, ...   Diamanto Kouniaki
# 5143  Department of Immunogenetics, National Blood T...  Abdelhafidh Hajjej
# 5144  Centro Investigaciones Biomédicas, Universidad...      Victor Monteón
# 5145  Department of Laboratory Medicine, Pusan Natio...         Jongmin Kim
#
# [5135 rows x 12 columns]

# %% [markdown]
# Printing the published papers count for every years

# %%
# Counting the number of papers published each year
papers_published_per_year = articles_df['Year'].value_counts().sort_index()

# Displaying the count of papers published each year
print(papers_published_per_year)
# Out:
# 1979      3
# 1980      9
# 1983      1
# 1984      1
# 1985      1
# 1991      1
# 1992      3
# 1994      1
# 1996      3
# 1997      3
# 1998      3
# 1999     40
# 2000    174
# 2001    188
# 2002    181
# 2003    178
# 2004    180
# 2005    198
# 2006    176
# 2007    230
# 2008    182
# 2009    183
# 2010    196
# 2011    238
# 2012    241
# 2013    236
# 2014    225
# 2015    224
# 2016    248
# 2017    196
# 2018    206
# 2019    198
# 2020    257
# 2021    248
# 2022    250
# 2023    232
# 2024      1
# Name: Year, dtype: int64

# %% [markdown]
# Displaying the author dataframe

# %%
IPD.display(author_df)
# Out:
#            PMID  AuthorN AuthorForename    AuthorLastname AuthorInitials  \
# 0      10551415        1              N            Yamada              N
# 1      10551415        2              Y          Ishikawa              Y
# 2      10551415        3              T           Dumrese              T
# 3      10551415        4              K          Tokunaga              K
# 4      10551415        5              T              Juji              T
# ...         ...      ...            ...               ...            ...
# 43159  38065105        3     Josefina G       Ancona-León             JG
# 43160  38065105        4          Gicel  Gutiérrez-Torres              G
# 43161  38073008        1        Jongmin               Kim              J
# 43162  38073008        2      Kyung-Hwa              Shin             KH
# 43163  38073008        3      Hyung-Hoi               Kim             HH
#
#                                        AuthorAffiliation
# 0      Division of Viral Immunology, Center for AIDS ...
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 43159  Facultad de Ciencias Químico Biológicas, Unive...
# 43160  Hospital General de Especialidades Dr. Javier ...
# 43161  Department of Laboratory Medicine, Pusan Natio...
# 43162  Department of Laboratory Medicine, Pusan Natio...
# 43163  Department of Laboratory Medicine, Pusan Natio...
#
# [43164 rows x 6 columns]

# %% [markdown]
# Finding the missing values count of author dataframe

# %%
authors_missing_count = author_df.isnull().sum()
IPD.display(authors_missing_count)
# Out:
# PMID                     0
# AuthorN                  0
# AuthorForename           5
# AuthorLastname           0
# AuthorInitials          37
# AuthorAffiliation    21077
# dtype: int64

# %% [markdown]
# Adding the column FullName by adding Forename and Lastname of the researchers using astype(str) to find the Publication count for the analysis part.

# %%
# creating copy dataframe for authors to avoid copy slice errors because it was showing error like that while running without the copy dataframe
author_df = author_df.copy()

#Creating the full name column
author_df['FullName'] = author_df['AuthorForename'].astype(str) + ' ' + author_df['AuthorLastname'].astype(str)

# Displaying the DataFrame with the 'FullName' column
author_df
# Out:
#            PMID  AuthorN AuthorForename    AuthorLastname AuthorInitials  \
# 0      10551415        1              N            Yamada              N
# 1      10551415        2              Y          Ishikawa              Y
# 2      10551415        3              T           Dumrese              T
# 3      10551415        4              K          Tokunaga              K
# 4      10551415        5              T              Juji              T
# ...         ...      ...            ...               ...            ...
# 43159  38065105        3     Josefina G       Ancona-León             JG
# 43160  38065105        4          Gicel  Gutiérrez-Torres              G
# 43161  38073008        1        Jongmin               Kim              J
# 43162  38073008        2      Kyung-Hwa              Shin             KH
# 43163  38073008        3      Hyung-Hoi               Kim             HH
#
#                                        AuthorAffiliation  \
# 0      Division of Viral Immunology, Center for AIDS ...
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 43159  Facultad de Ciencias Químico Biológicas, Unive...
# 43160  Hospital General de Especialidades Dr. Javier ...
# 43161  Department of Laboratory Medicine, Pusan Natio...
# 43162  Department of Laboratory Medicine, Pusan Natio...
# 43163  Department of Laboratory Medicine, Pusan Natio...
#
#                      FullName
# 0                    N Yamada
# 1                  Y Ishikawa
# 2                   T Dumrese
# 3                  K Tokunaga
# 4                      T Juji
# ...                       ...
# 43159  Josefina G Ancona-León
# 43160  Gicel Gutiérrez-Torres
# 43161             Jongmin Kim
# 43162          Kyung-Hwa Shin
# 43163           Hyung-Hoi Kim
#
# [43164 rows x 7 columns]

# %% [markdown]
# Clearing the missing value rows based on the unavilability of data(PMID,AuthorForname,AuthorLastname and AuthorInitials)

# %%
# Dropping rows where 'PMID', 'Year', 'AuthorForename', or 'AuthorLastname' are missing in the authors dataframe
authors_df = author_df.dropna(subset=['PMID','AuthorForename', 'AuthorLastname','AuthorInitials'])
missing_values_cleaned_authors = authors_df.isnull().sum()
IPD.display(missing_values_cleaned_authors)
# Out:
# PMID                     0
# AuthorN                  0
# AuthorForename           0
# AuthorLastname           0
# AuthorInitials           0
# AuthorAffiliation    21060
# FullName                 0
# dtype: int64

# %% [markdown]
# Displaying the author dataframe after clearing the missing values

# %%
IPD.display(authors_df)
# Out:
#            PMID  AuthorN AuthorForename    AuthorLastname AuthorInitials  \
# 0      10551415        1              N            Yamada              N
# 1      10551415        2              Y          Ishikawa              Y
# 2      10551415        3              T           Dumrese              T
# 3      10551415        4              K          Tokunaga              K
# 4      10551415        5              T              Juji              T
# ...         ...      ...            ...               ...            ...
# 43159  38065105        3     Josefina G       Ancona-León             JG
# 43160  38065105        4          Gicel  Gutiérrez-Torres              G
# 43161  38073008        1        Jongmin               Kim              J
# 43162  38073008        2      Kyung-Hwa              Shin             KH
# 43163  38073008        3      Hyung-Hoi               Kim             HH
#
#                                        AuthorAffiliation  \
# 0      Division of Viral Immunology, Center for AIDS ...
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 43159  Facultad de Ciencias Químico Biológicas, Unive...
# 43160  Hospital General de Especialidades Dr. Javier ...
# 43161  Department of Laboratory Medicine, Pusan Natio...
# 43162  Department of Laboratory Medicine, Pusan Natio...
# 43163  Department of Laboratory Medicine, Pusan Natio...
#
#                      FullName
# 0                    N Yamada
# 1                  Y Ishikawa
# 2                   T Dumrese
# 3                  K Tokunaga
# 4                      T Juji
# ...                       ...
# 43159  Josefina G Ancona-León
# 43160  Gicel Gutiérrez-Torres
# 43161             Jongmin Kim
# 43162          Kyung-Hwa Shin
# 43163           Hyung-Hoi Kim
#
# [43127 rows x 7 columns]

# %% [markdown]
# Displaying the paper_counts dataframe

# %%
IPD.display(paper_counts_df)
# Out:
#      Year    Count
# 0    1799        1
# 1    1801        1
# 2    1802        1
# 3    1805        1
# 4    1866        1
# ..    ...      ...
# 138  2020  1132241
# 139  2021  1277048
# 140  2022  1324650
# 141  2023  1302390
# 142  2024    15611
#
# [143 rows x 2 columns]

# %% [markdown]
# Finding the missing value

# %%
papers_missing_count = paper_counts_df.isnull().sum()
IPD.display(papers_missing_count)
# Out:
# Year     0
# Count    0
# dtype: int64

# %% [markdown]
# Plotting the Paper_counts dataframe with year and count

# %%
import matplotlib.pyplot as plt

# Plotting a time series graph for the paper counts
plt.figure(figsize=(12, 6))
plt.plot(paper_counts_df['Year'], paper_counts_df['Count'], marker='o', linestyle='-', color='b')
plt.title('Number of Papers Published in PubMed Each Year')
plt.xlabel('Year')
plt.ylabel('Number of Papers')
plt.grid(True)
plt.show()

# %% [markdown]
# Finding the top authors using the Author dataframe by FullName and publication count

# %%
# Counting publications for each author considering their FullName
full_name_publication_counts = authors_df.groupby(['FullName']).size().reset_index(name='PublicationCount')

# Sorting the authors based on their publication count from the year 1999-2024
Publication_counts = full_name_publication_counts.sort_values(by='PublicationCount', ascending=False)
Publication_counts
# Out:
#                       FullName  PublicationCount
# 19071                  P Y Lin                58
# 12521                 K L Yang                54
# 12204           Julio Granados                42
# 13577           Kuo-Liang Yang                39
# 6548   Esteban Arrieta-Bolaños                38
# ...                        ...               ...
# 10460             J R Yannelli                 1
# 10459                 J R Wyer                 1
# 10458           J R Wunderlich                 1
# 10456               J R Turton                 1
# 27826          Łukasz Matusiak                 1
#
# [27827 rows x 2 columns]

# %% [markdown]
# Creating the top 20 activite researchers dataframe from 1979-2024

# %%
# Displaying top authors from the year 1979-2024
top_20_active_researchers = Publication_counts.head(20)
top_20_active_researchers
# Out:
#                              FullName  PublicationCount
# 19071                         P Y Lin                58
# 12521                        K L Yang                54
# 12204                  Julio Granados                42
# 13577                  Kuo-Liang Yang                39
# 6548          Esteban Arrieta-Bolaños                38
# 19792                       Py-Yu Lin                37
# 20855                Rodrigo Barquera                37
# 6027                   Edmond J Yunis                37
# 26668                 Yasuo Morishima                36
# 11596                  Joaquín Zúñiga                35
# 16455                 Mary Carrington                34
# 5470   Diana Iraíz Hernández-Zaragoza                33
# 1208             Alicia Bravo-Acevedo                32
# 1064                 Alessandro Sette                32
# 3281                       C K Hurley                32
# 3649           Carolina Bekker-Méndez                32
# 23092                 Stephen Clayton                32
# 1451               Anastasiia Ananeva                30
# 21366                         S K Lee                30
# 10256                            J He                29

# %% [markdown]
# Using barplot to show the counts of publications of the top 20 researchers from 1979 to 2024

# %%
#importing seaborn for the visualisation
import seaborn as sns
plt.figure(figsize=(10, 6))
sns.barplot(x='PublicationCount', y='FullName', hue='FullName', data=top_20_active_researchers, palette='viridis')
plt.title('Top 20 Authors in HLA-A Research by Publication Count')
plt.xlabel('Publication Count')
plt.show()

# %% [markdown]
# Creating the network based on the Full Name from top_20_active_researchers with the authors df to find the co-authors by using pmid

# %%
import networkx as nx
import matplotlib.pyplot as plt
# Creating the subset of the authors dataframe focusing on the top authors
top_author_names = top_20_active_researchers['FullName'].tolist()
top_20_active_researchers = authors_df[authors_df['FullName'].isin(top_author_names)]

# Creating the co-authorship network by considering fullnames with use of pmid
G_full_name = nx.Graph()
for pmid, group in top_20_active_researchers.groupby('PMID'):
    authors = group['FullName'].tolist()
    for author in authors:
        if author not in G_full_name:
            G_full_name.add_node(author)
        for coauthor in authors:
            if author != coauthor:
                G_full_name.add_edge(author, coauthor)

# Extracting connected components (collaboration networks)
connected_components = list(nx.connected_components(G_full_name))
#printing the connected components
connected_components
# Out:
# [{'C K Hurley', 'J He'},
#  {'Alicia Bravo-Acevedo',
#   'Carolina Bekker-Méndez',
#   'Diana Iraíz Hernández-Zaragoza',
#   'Edmond J Yunis',
#   'Esteban Arrieta-Bolaños',
#   'Joaquín Zúñiga',
#   'Julio Granados',
#   'Rodrigo Barquera',
#   'Stephen Clayton'},
#  {'Alessandro Sette', 'Mary Carrington', 'Yasuo Morishima'},
#  {'K L Yang', 'P Y Lin', 'S K Lee'},
#  {'Kuo-Liang Yang', 'Py-Yu Lin'},
#  {'Anastasiia Ananeva'}]

# %% [markdown]
# plotting the network diagram to understand better

# %%
# Drawing the network graph with spacing
plt.figure(figsize=(15, 15))
# Increasing the 'k' parameter to increase repulsive force between nodes
pos = nx.spring_layout(G_full_name, k=3.0, iterations=100)

# Drawing the nodes and edges
nx.draw_networkx_nodes(G_full_name, pos, node_color='skyblue', edgecolors='black')
nx.draw_networkx_edges(G_full_name, pos, edge_color='gray', alpha=0.9)

# Drawing the labels
for node, (x, y) in pos.items():
    plt.text(x, y, node, fontsize=8, ha='center', va='center')

# Giving the  title and remove axis
plt.title("Co-authorship Network in HLA-A Research")
plt.axis('off')

# Show the plot
plt.show()
